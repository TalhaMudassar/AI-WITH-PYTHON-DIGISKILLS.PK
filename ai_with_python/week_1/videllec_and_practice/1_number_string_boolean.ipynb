# %%
age = 25
print(age)
# Out:
# 25

# %%
score = 3.5
print(score)
# Out:
# 3.5

# %%
type(score)
# Out:
# float

# %%
print(score +1)
# Out:
# 4.5

# %%
name = "talha mudassar"
print(name)
# Out:
# talha mudassar

# %%
print(name + " is good" )
# Out:
# talha mudassar is good

# %%
is_passed = True
print(is_passed)
# Out:
# True
