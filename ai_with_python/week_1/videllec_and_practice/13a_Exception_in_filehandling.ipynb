# %%
with open("missing.txt","r") as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open("missing.txt","r") as file:
#       2     print(file.read())
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'missing.txt'

# %%
try:
    with open("missing.txt","r") as file:
        print("file.read")
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %% [markdown]
# ---
# ### if file not found
# ### Create with name and age  and than read

# %%
file_name = "myinfo.txt"
name = "Github copilot"
age = 1

# %%
try:
    with open(file_name,"r") as fin:
        print(fin.read())
    
except FileNotFoundError:
    with open(file_name,"w") as fout:
        fout.write(f"{name}\n{age}")
    with open(file_name,"r") as filee:
        print(filee.read())
# Out:
# Github copilot
# 1
