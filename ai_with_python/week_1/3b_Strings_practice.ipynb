# %% [markdown]
# ### 1. Calculate string length.

# %%
name = "Talha hello"
count = 0
for char in name:
    count += 1
print(f"Total characters are {count}")
# Out:
# Total characters are 11

# %% [markdown]
# ### 2. Count character frequency in a string.

# %%
str1 = "google.com"

counting = {}

for char in str1:
    if char in counting:
        counting[char] += 1
    else:
        counting[char] = 1
        
print(counting)
# Out:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %% [markdown]
# ### 3. Get string of first and last 2 chars.

# %%
name = "TalhaMudassar"

firsttwo = name[0:2]
lasttwo = name[-2:]

print(firsttwo + lasttwo)
# Out:
# Taar

# %% [markdown]
# ### Replace first char occurrences with $.

# %%
str1 = "restart"

preserve = str1[0]

str1 = str1.replace(preserve, "$")

new_str1 = preserve + str1[1:]

print(new_str1)
# Out:
# resta$t

# %% [markdown]
# ### 5. Swap first 2 chars of 2 strings.

# %%
string1 = "talha"
string2 = "mudassar"

first2_str1 = string2[:1] + string1[1:]

first2_str2 = string1[:1] + string2[1:]

resultant_string = first2_str1+" "+first2_str2

print(resultant_string)
# Out:
# malha tudassar

# %% [markdown]
# ### Add ing or ly to a string.
#
# Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

# %%
string1 = input("Enter string here :  ")

count = 0
for i in string1:
    count += 1

if count > 2:
    if string1[-3:] == "ing":
        string1 += "ly"
    else:
        string1 += "ing"
        
print(string1)

# %% [markdown]
# ### 7. Replace 'not'...'poor' with 'good'.
#
# Write a Python program to find the first appearance of the substrings 'not' and 'poor' in a given string. If 'not' follows 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string.
# Sample String : 'The lyrics is not that poor!'
# 'The lyrics is poor!'
# Expected Result : 'The lyrics is good!'
# 'The lyrics is poor!'

# %%
string1 = "The lyrics is not that poor!"

new_str1 = string1.replace("poor","good")

print(new_str1)
# Out:
# The lyrics is not that good!

# %% [markdown]
# ### 8. Find longest word in a list.
#
# Write a Python function that takes a list of words and return the longest word and the length of the longest one.
# Sample Output:
# Longest word: Exercises
# Length of the longest word: 9

# %%
list_1 = ["Hello", "kesa", "ho", "saab", "karieeat"]

length = 0
longest_word = ""

for wor in list_1:
    temp = 0

    for ch in wor:
        temp += 1

    if temp > length:
        length = temp
        longest_word = wor

print(f"{longest_word} is the highest length")
print(f"Length of the longest word: {length}")
# Out:
# karieeat is the highest length
# Length of the longest word: 8

# %% [markdown]
# ### 9. Remove nth character from a string.
# Write a Python program to remove the nth index character from a nonempty string.

# %%
word = "talha"

index_ch = int(input("Enter index to remove: "))

firsthalf = word[:index_ch]

lasthalf = word[index_ch + 1 :]

final_output = firsthalf + lasthalf

print(f"After remvoing string are : {final_output}")
# Out:
# After remvoing string are : tala

# %% [markdown]
# ### 10. Swap first and last chars of a string.
# Write a Python program to change a given string to a newly string where the first and last chars have been exchanged.

# %%
string_1 = "strawberry"

print(f"{string_1[-1:]}{string_1[1:-1]}{string_1[:1]}")
# Out:
# ytrawberrs

# %% [markdown]
# ### 11. Remove odd index chars from a string.
# Write a Python program to remove characters that have odd index values in a given string.

# %%
string_1 = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

print(f"{string_1[0:-1:2]}")
# Out:
# ACEGIKMOQSUWY

# %% [markdown]
# ### 12. Count word occurrences in a sentence.
# Write a Python program to count the occurrences of each word in a given sentence.

# %%
sentences = "the quick brown fox jumps over the lazy dog"

counts = dict()

words = sentences.split()

for word in words:
    if word in counts:
        counts[word] += 1
    else:
        counts[word] = 1
    
print(counts)
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1}

# %% [markdown]
# ### 13. Display input in upper and lower case.
# Write a Python script that takes input from the user and displays that input back in upper and lower cases.

# %%
sentence = "Hello How are you "

lower_words = sentence.lower()
upper_words = sentence.upper()

print("Lower words are :", lower_words)
print("Upper words are :", upper_words)
# Out:
# Lower words are : hello how are you
# Upper words are : HELLO HOW ARE YOU
