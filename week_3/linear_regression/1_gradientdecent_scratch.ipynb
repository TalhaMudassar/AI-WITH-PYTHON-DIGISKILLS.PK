# %% [markdown]
# ### RAW DERIVATIVE OF SLOPE INTERCEPT

# %%
import numpy as np

# %%
learning_rate = 0.01
epochs = 5
x = np.array([1,2,3,4,5])
y = np.array([3,4,2,5,6])

# %%
m,b = 0.0, 0.0
n = len(x)

# %%
for i in range(epochs):
    y_pred = m*n + b
    cost = ((y_pred - y) ** 2).mean()
    derivative_m = (-2/n) * sum(x * (y - y_pred))
    derivative_b = (-2/n) * sum(y - y_pred)
    m -= learning_rate * derivative_m
    b -= learning_rate * derivative_b
    print(f"Epoch {i+1}/{epochs}, Cost: {cost}, m: {m}, b: {b}")
# Out:
# Epoch 1/5, Cost: 18.0, m: 0.268, b: 0.08
# Epoch 2/5, Cost: 8.6564, m: 0.45080000000000003, b: 0.1316
# Epoch 3/5, Cost: 4.60628736, m: 0.5756640000000001, b: 0.16388799999999998
# Epoch 4/5, Cost: 2.9173655152639992, m: 0.6611315200000001, b: 0.18304383999999996
# Epoch 5/5, Cost: 2.2614262174580735, m: 0.7198094336, b: 0.19326981119999995
