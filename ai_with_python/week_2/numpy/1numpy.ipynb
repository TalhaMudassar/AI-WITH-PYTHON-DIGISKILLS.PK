# %% [markdown]
# ### Installing the numpy

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ---
# # code

# %%
import numpy as np 
import time

# %%
arr = np.array([[1,2,3],[4,5,6]])

print(arr.shape)   # like 2 lists + 3 elements

print(arr.ndim) # use for dimensions 

print(arr.dtype)  # use for checking the array type
# Out:
# (2, 3)
# 2
# int64

# %% [markdown]
# ---
# ### Time difference + output

# %%
py_list = list(range(1_000_000))
py_result = []
start_time = time.time()    
for i in py_list:
    py_result.append(i+5)
end_time = time.time()
print("Python list time:",end_time - start_time)
# Out:
# Python list time: 0.2225182056427002

# %%
np_array = np.arange(1_000_000)
start_time = time.time()
np.result = np_array + 5
end_time = time.time()
print("Numpy array are:",end_time - start_time)
# Out:
# Numpy array are: 0.006003379821777344
