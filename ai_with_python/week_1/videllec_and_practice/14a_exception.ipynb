# %% [markdown]
# ### Exception Handling

# %%
num = int(input("Enter a number :"))
print(10/num)
# Out:
# 1.6666666666666667

# %%
try:
    number = int(input("Enter a Number:"))
    print(10/number)

except ZeroDivisionError:
    print("You cannot divide by zero")
    
except ValueError:
    print("this is not a number input")
    
except Exception as e:
    print(f"An unexpected error are occured: {e}")
# Out:
# 1.4285714285714286

# %% [markdown]
# ---
#
# # Exception + else + finally

# %%
try:
    print("Running the code")
except:
    print("Error Found")
else:
    print("No error found")
finally:
    print("Done !")
# Out:
# Running the code
# No error found
# Done !

# %% [markdown]
# ---
# # Raise Exception

# %%
age = -3

if age < 0:
    raise ValueError("Age cannot be negtive")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 age = -3
#       3 if age < 0:
# ----> 4     raise ValueError("Age cannot be negtive")
#
# ValueError: Age cannot be negtive
