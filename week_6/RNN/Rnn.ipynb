# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import pandas as pd
import numpy as np

# %%
# Load the data
df_loaded = pd.read_csv('module_157_data.csv')

# Separate features and target
X = df_loaded.drop('target', axis=1).values
y = df_loaded['target'].values

# RESHAPE: From (2000, 10) to (2000, 10, 1)
# This adds the "feature" dimension required by RNN
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# Build and compile
model = Sequential([
    # SimpleRNN is the basic recurrent layer
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train
model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6550 - loss: 0.6483 - val_accuracy: 0.6750 - val_loss: 0.5716
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.4283 - val_accuracy: 0.8350 - val_loss: 0.3953
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8350 - loss: 0.3555 - val_accuracy: 0.7900 - val_loss: 0.4198
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8519 - loss: 0.3352 - val_accuracy: 0.8600 - val_loss: 0.3170
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 0.2861 - val_accuracy: 0.8575 - val_loss: 0.3132
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9006 - loss: 0.2572 - val_accuracy: 0.8300 - val_loss: 0.3692
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9019 - loss: 0.2440 - val_accuracy: 0.8650 - val_loss: 0.2606
# Epoch 8/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9038 - loss: 0.2267 - val_accuracy: 0.8850 - val_loss: 0.2515
# Epoch 9/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 0.2310 - val_accuracy: 0.8925 - val_loss: 0.2583
# Epoch 10/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9200 - loss: 0.2061 - val_accuracy: 0.8875 - val_loss: 0.2458
# Epoch 11/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9069 - loss: 0.2070 - val_accuracy: 0.8900 - val_loss: 0.2263
# Epoch 12/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9256 - loss: 0.1869 - val_accuracy: 0.8900 - val_loss: 0.2132
# Epoch 13/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9344 - loss: 0.1787 - val_accuracy: 0.8875 - val_loss: 0.2141
# Epoch 14/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9194 - loss: 0.1865 - val_accuracy: 0.9000 - val_loss: 0.2034
# Epoch 15/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9206 - loss: 0.1946 - val_accuracy: 0.9050 - val_loss: 0.1920
# Epoch 16/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9444 - loss: 0.1634 - val_accuracy: 0.9000 - val_loss: 0.1926
# Epoch 17/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9337 - loss: 0.1654 - val_accuracy: 0.9050 - val_loss: 0.1829
# Epoch 18/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9406 - loss: 0.1564 - val_accuracy: 0.9075 - val_loss: 0.1783
# Epoch 19/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9413 - loss: 0.1506 - val_accuracy: 0.9100 - val_loss: 0.1764
# Epoch 20/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9413 - loss: 0.1492 - val_accuracy: 0.9125 - val_loss: 0.1696

# %%
# Evaluate and print only the accuracy
print(f"\nFinal Accuracy: {model.evaluate(X, y, verbose=0)[1]:.4f}")
# Out:
# Final Accuracy: 0.9425
