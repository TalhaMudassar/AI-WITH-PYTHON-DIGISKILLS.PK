# %% [markdown]
# ### Inheritance in Python - Parent & Child Classes

# %%
class Animal:
    def speak(self):
        print("Some sound")

# %%
class Dog(Animal):
    pass

# %%
dog1 = Dog()

# %%
dog1.speak()
# Out:
# Some sound

# %%
class Dog(Animal):
    def bark(self):
        print("Woof!")

# %%
childdog = Dog()

# %%
childdog.bark()
# Out:
# Woof!

# %% [markdown]
# # Method Overriding

# %%
class Animal:
    def speak(self):
        print("Some sound")

# %%
class Dog(Animal):
    def speak(self):
        print("Woof! Woof!")

# %%
dog1 = Dog()

# %%
dog1.speak()
# Out:
# Woof! Woof!
