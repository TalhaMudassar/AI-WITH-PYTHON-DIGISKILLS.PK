# %% [markdown]
# # Python Modules

# %%
#math library
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt
print(sqrt(25))
# Out:
# 5.0

# %%
import mymodule

mymodule.greeting()
# Out:
# Hello here am is module file
