# %%
age = "34"

# %%
print(age)
# Out:
# 34

# %%
type(age)
# Out:
# str

# %%
print(int(age)+1)
# Out:
# 35

# %%
type(age)
# Out:
# str

# %%
age = input("Enter your age please ")

# %%
type(age)
# Out:
# str

# %%
myage = int(age)

# %%
type(myage)
# Out:
# int

# %%
print(myage)
# Out:
# 23
